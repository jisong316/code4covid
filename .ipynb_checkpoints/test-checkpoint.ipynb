# %%
# Neural Net Layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import nltk
import numpy
import tensorflow
import random
import json
import pickle

from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()

with open("intents.json") as file:
    data = json.load(file)

# %%
try:
    with open("data.pickle", "rb") as f:
        words, labels, training, output = pickle.load(f)
except:
    words = []
    labels = []
    docs_x = []
    docs_y = []

    for intent in data["intents"]:
        for pattern in intent["patterns"]:
            wrds = nltk.word_tokenize(pattern)
            words.extend(wrds)
            docs_x.append(wrds)
            docs_y.append(intent["tag"])

        if intent["tag"] not in labels:
            labels.append(intent["tag"])

    words = [stemmer.stem(w.lower()) for w in words if w != "?"]
    words = sorted(list(set(words)))

    labels = sorted(labels)

    training = []
    output = []

    out_empty = [0 for _ in range(len(labels))]

    for x, doc in enumerate(docs_x):
        bag = []

        wrds = [stemmer.stem(w.lower()) for w in doc]

        for w in words:
            if w in wrds:
                bag.append(1)
            else:
                bag.append(0)

        output_row = out_empty[:]
        output_row[labels.index(docs_y[x])] = 1

        training.append(bag)
        output.append(output_row)


    training = numpy.array(training)
    output = numpy.array(output)

    with open("data.pickle", "wb") as f:
        pickle.dump((words, labels, training, output), f)

# net = tflearn.input_data(shape=[None, len(training[0])])
# net = tflearn.fully_connected(net, 8)
# net = tflearn.fully_connected(net, 8)
# net = tflearn.fully_connected(net, len(output[0]), activation="softmax")
# net = tflearn.regression(net)

# model = tflearn.DNN(net)

tensorflow.keras.backend.clear_session()

model = tensorflow.keras.Sequential([
    tensorflow.keras.layers.Dense(8, input_shape=training[0].shape),
    tensorflow.keras.layers.Dense(8),
    tensorflow.keras.layers.Dense(8),
    tensorflow.keras.layers.Dense(8),
    tensorflow.keras.layers.Dense(len(output[0]), activation="softmax") ])
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(training, output, epochs=200, batch_size=8)
model.save("model.keras")

#you need to feed it the input shape of the first x variable
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 376
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 54
# =================================================================
# Total params: 646
# Trainable params: 646
# Non-trainable params: 0
# _________________________________________________________________
# Train on 26 samples
# Epoch 1/200
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fd6c7aff8c0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fd6c7aff8c0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 26/26 [==============================] - 1s 53ms/sample - loss: 1.7876 - accuracy: 0.1538
# Epoch 2/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 1.7679 - accuracy: 0.1923
# Epoch 3/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.7524 - accuracy: 0.1923
# Epoch 4/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.7356 - accuracy: 0.1923
# Epoch 5/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.7211 - accuracy: 0.1923
# Epoch 6/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.7070 - accuracy: 0.2308
# Epoch 7/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.6935 - accuracy: 0.2692
# Epoch 8/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.6790 - accuracy: 0.2692
# Epoch 9/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.6652 - accuracy: 0.2692
# Epoch 10/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 1.6512 - accuracy: 0.3077
# Epoch 11/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 1.6363 - accuracy: 0.3462
# Epoch 12/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.6210 - accuracy: 0.4231
# Epoch 13/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 1.6053 - accuracy: 0.4615
# Epoch 14/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.5886 - accuracy: 0.5000
# Epoch 15/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.5733 - accuracy: 0.5000
# Epoch 16/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.5554 - accuracy: 0.5000
# Epoch 17/200
# 26/26 [==============================] - 0s 3ms/sample - loss: 1.5368 - accuracy: 0.5385
# Epoch 18/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.5191 - accuracy: 0.5769
# Epoch 19/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 1.5011 - accuracy: 0.5769
# Epoch 20/200
# 26/26 [==============================] - 0s 3ms/sample - loss: 1.4784 - accuracy: 0.5769
# Epoch 21/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1.4583 - accuracy: 0.5769
# Epoch 22/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 1
200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0777 - accuracy: 1.0000
# Epoch 117/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0752 - accuracy: 1.0000
# Epoch 118/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0726 - accuracy: 1.0000
# Epoch 119/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0705 - accuracy: 1.0000
# Epoch 120/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0676 - accuracy: 1.0000
# Epoch 121/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0651 - accuracy: 1.0000
# Epoch 122/200
# 26/26 [==============================] - 0s 664us/sample - loss: 0.0626 - accuracy: 1.0000
# Epoch 123/200
# 26/26 [==============================] - 0s 747us/sample - loss: 0.0606 - accuracy: 1.0000
# Epoch 124/200
# 26/26 [==============================] - 0s 688us/sample - loss: 0.0579 - accuracy: 1.0000
# Epoch 125/200
# 26/26 [==============================] - 0s 721us/sample - loss: 0.0555 - accuracy: 1.0000
# Epoch 126/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0532 - accuracy: 1.0000
# Epoch 127/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0515 - accuracy: 1.0000
# Epoch 128/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0496 - accuracy: 1.0000
# Epoch 129/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0477 - accuracy: 1.0000
# Epoch 130/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0461 - accuracy: 1.0000
# Epoch 131/200
# 26/26 [==============================] - 0s 3ms/sample - loss: 0.0443 - accuracy: 1.0000
# Epoch 132/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0428 - accuracy: 1.0000
# Epoch 133/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0414 - accuracy: 1.0000
# Epoch 134/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0401 - accuracy: 1.0000
# Epoch 135/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0389 - accuracy: 1.0000
# Epoch 136/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0375 - accuracy: 1.0000
# Epoch 137/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0363 - accuracy: 1.0000
# Epoch 138/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0352 - accuracy: 1.0000
# Epoch 139/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0343 - accuracy: 1.0000
# Epoch 140/200
# 26/26 [==============================] - 0s 968us/sample - loss: 0.0334 - accuracy: 1.0000
# Epoch 141/200
# 26/26 [==============================] - 0s 772us/sample - loss: 0.0323 - accuracy: 1.0000
# Epoch 142/200
# 26/26 [==============================] - 0s 716us/sample - loss: 0.0311 - accuracy: 1.0000
# Epoch 143/200
# 26/26 [==============================] - 0s 816us/sample - loss: 0.0300 - accuracy: 1.0000
# Epoch 144/200
# 26/26 [==============================] - 0s 696us/sample - loss: 0.0296 - accuracy: 1.0000
# Epoch 145/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0287 - accuracy: 1.0000
# Epoch 146/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0281 - accuracy: 1.0000
# Epoch 147/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0274 - accuracy: 1.0000
# Epoch 148/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0267 - accuracy: 1.0000
# Epoch 149/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0260 - accuracy: 1.0000
# Epoch 150/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0253 - accuracy: 1.0000
# Epoch 151/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0244 - accuracy: 1.0000
# Epoch 152/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0236 - accuracy: 1.0000
# Epoch 153/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0231 - accuracy: 1.0000
# Epoch 154/200
# 26/26 [==============================] - 0s 960us/sample - loss: 0.0224 - accuracy: 1.0000
# Epoch 155/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0218 - accuracy: 1.0000
# Epoch 156/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0213 - accuracy: 1.0000
# Epoch 157/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0207 - accuracy: 1.0000
# Epoch 158/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0202 - accuracy: 1.0000
# Epoch 159/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0198 - accuracy: 1.0000
# Epoch 160/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0193 - accuracy: 1.0000
# Epoch 161/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0188 - accuracy: 1.0000
# Epoch 162/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0183 - accuracy: 1.0000
# Epoch 163/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0179 - accuracy: 1.0000
# Epoch 164/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0174 - accuracy: 1.0000
# Epoch 165/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0171 - accuracy: 1.0000
# Epoch 166/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0167 - accuracy: 1.0000
# Epoch 167/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0164 - accuracy: 1.0000
# Epoch 168/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0161 - accuracy: 1.0000
# Epoch 169/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0158 - accuracy: 1.0000
# Epoch 170/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0155 - accuracy: 1.0000
# Epoch 171/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0152 - accuracy: 1.0000
# Epoch 172/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0149 - accuracy: 1.0000
# Epoch 173/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0146 - accuracy: 1.0000
# Epoch 174/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0143 - accuracy: 1.0000
# Epoch 175/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0140 - accuracy: 1.0000
# Epoch 176/200
# 26/26 [==============================] - 0s 830us/sample - loss: 0.0137 - accuracy: 1.0000
# Epoch 177/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0135 - accuracy: 1.0000
# Epoch 178/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0132 - accuracy: 1.0000
# Epoch 179/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0130 - accuracy: 1.0000
# Epoch 180/200
# 26/26 [==============================] - 0s 890us/sample - loss: 0.0128 - accuracy: 1.0000
# Epoch 181/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0125 - accuracy: 1.0000
# Epoch 182/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0123 - accuracy: 1.0000
# Epoch 183/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0121 - accuracy: 1.0000
# Epoch 184/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0119 - accuracy: 1.0000
# Epoch 185/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0117 - accuracy: 1.0000
# Epoch 186/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0115 - accuracy: 1.0000
# Epoch 187/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0113 - accuracy: 1.0000
# Epoch 188/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0111 - accuracy: 1.0000
# Epoch 189/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0109 - accuracy: 1.0000
# Epoch 190/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0107 - accuracy: 1.0000
# Epoch 191/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0105 - accuracy: 1.0000
# Epoch 192/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0104 - accuracy: 1.0000
# Epoch 193/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0102 - accuracy: 1.0000
# Epoch 194/200
# 26/26 [==============================] - 0s 925us/sample - loss: 0.0100 - accuracy: 1.0000
# Epoch 195/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0099 - accuracy: 1.0000
# Epoch 196/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0097 - accuracy: 1.0000
# Epoch 197/200
# 26/26 [==============================] - 0s 1ms/sample - loss: 0.0096 - accuracy: 1.0000
# Epoch 198/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0095 - accuracy: 1.0000
# Epoch 199/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0093 - accuracy: 1.0000
# Epoch 200/200
# 26/26 [==============================] - 0s 2ms/sample - loss: 0.0091 - accuracy: 1.0000

# %%
try:
    model = tensorflow.keras.models.load_model("model.keras")
except:
    model.fit(training, output, epochs=200, batch_size=8)
    model.save("model.keras")

def bag_of_words(s, words):
    bag = [0 for _ in range(len(words))]

    s_words = nltk.word_tokenize(s)
    s_words = [stemmer.stem(word.lower()) for word in s_words]

    for se in s_words:
        for i, w in enumerate(words):
            if w == se:
                bag[i] = 1
            
    return numpy.array(bag)


def chat():
    print("I'm the #codeforcovid bot (type quit to stop)!")
    while True:
        inp = input("You: ")
        if inp.lower() == "quit":
            break

        results = model.predict([[bag_of_words(inp, words)]])
        results_index = numpy.argmax(results)
        tag = labels[results_index]
        if numpy.argmax(results) < 0.8:
            print("I don't quite get that. Ask me something else?")
        else:
            for tg in data["intents"]:
                if tg['tag'] == tag:
                    responses = tg['responses']
            print(random.choice(responses))

chat()
# Out:
# I'm the #codeforcovid bot (type quit to stop)!
# You: hello what are covid symptoms
# Common symptoms for covid-19 include a dry cough, fever and tiredness. Less common symptoms include loss of smell, dizziness and rashes.
# You: thanks goodbye
# Goodbye!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2b0455ef95d7> in <module>
#      37             print(random.choice(responses))
#      38
# ---> 39 chat()
#
# <ipython-input-7-2b0455ef95d7> in chat()
#      22     print("I'm the #codeforcovid bot (type quit to stop)!")
#      23     while True:
# ---> 24         inp = input("You: ")
#      25         if inp.lower() == "quit":
#      26             break
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:
